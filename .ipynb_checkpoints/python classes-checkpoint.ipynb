# %%
print("Welcome to Women in AI Fellowship!")
# Out:
# Welcome to Women in AI Fellowship!

# %%
print('Jesutomi')
# Out:
# Jesutomi

# %%
name = ' Jesutomi'
print(name)
# Out:
#  Jesutomi

# %%
text = "hello world"

print (text)
print (text.upper())
print (text.lower())
print (text.title())

print (text.replace("world","Python"))
print (text.split()) # ['hello',world']
# Out:
# hello world
# HELLO WORLD
# hello world
# Hello World
# hello Python
# ['hello', 'world']

# %%
text = "Python"
print (len(text))
# Out:
# 6

# %%
first = "Hello"
second = "Python"
print (first + ' ' + second)
print (first + second)
print (8+5)
print ('8' + '5')
# Out:
# Hello Python
# HelloPython
# 13
# 85

# %%
x,y=6,10
print(x, y)
y,x = x,y

print(x,y)
# Out:
# 6 10
# 10 6

# %%
x = 5
y = 10
print (x)
print (y)

a = x # a = 5
x = y # x = 10
y = a # y = 5

print(x)
print(y)
# Out:
# 5
# 10
# 10
# 5

# %%
#swapping
x =15
y = 10
print(x)
print(y)

a = x # a = 5
x = y # x = 10

y = a   # y =5

print(x)
print(y)
# Out:
# 15
# 10
# 10
# 15

# %%
C = 'Ilorin'


print (C.upper())
print (C.capitalize())
print (C.endswith("osun"))
# Out:
# ILORIN
# Ilorin
# False

# %%
print ("He said: \"go away\"")
# Out:
# He said: "go away"

# %%
# using positional and keyword Arguments
name = 'carina'
age = 22

print("My name is {0} and I am {1} years old.".format(name, age))
# Out:
# My name is carina and I am 22 years old.

# %%
# using f-strings (Recommended)
# Introduced in Python 3.6+, f-strings allow for easier string interpolation

name = "Halimah"
age = 22
print (f" My name is {name} and I am {age} years old.")
# Out:
#  My name is Halimah and I am 22 years old.

# %%
# Creating different types of lists

empty_list = []# Empty list
numbers = [[1, 2, 3], [4, 5,6]]
fruits = ["apple", "banana", "cashew"]
mixed = [1, "fish", 3.5, True]
nested_list =[[1,2,3], [4,5,6]]

print (numbers)
print (mixed)
# Out:
# [[1, 2, 3], [4, 5, 6]]
# [1, 'fish', 3.5, True]

# %%
names = ['Abiola', 'Benjamin', 'Zainab', ' Esther', 'Carina', 'Salamat']

print(names)
names[1]='Halimah'
print(names)
# Out:
# ['Abiola', 'Benjamin', 'Zainab', ' Esther', 'Carina', 'Salamat']
# ['Abiola', 'Halimah', 'Zainab', ' Esther', 'Carina', 'Salamat']

# %%
fruits = ["apple", "banana"]

print(fruits)
# Out:
# ['apple', 'banana']

# %%
fruits.append("cherry")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits = ["apple","banana"]
print(fruits)
# Out:
# ['apple', 'banana']

# %%
more_fruits =["cherry", "mango"]
fruits.extend(more_fruits)
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'mango']

# %%
items = ['Detergent', 'milk', 'shoe', 'fruit']
print(items)

# %%
items.insert(2, 'Beef')
print(items)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 items.insert(2, 'Beef')
#       2 print(items)
#
# NameError: name 'items' is not defined

# %%
fruits = ['apple', 'banana', 'cherry', 'apple']
print (fruits)
# Out:
# ['apple', 'banana', 'cherry', 'apple']

# %%
fruits.remove('apple')
print(fruits)
# Out:
# ['banana', 'cherry', 'apple']

# %%
names = ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'funmi', 'Tomi', 'Lola', 'Hannah']
print (names)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'funmi', 'Tomi', 'Lola', 'Hannah']

# %%
names.pop()
print(names)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'funmi', 'Tomi', 'Lola']

# %%
names.pop(4)
print(names)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Salamat', 'funmi', 'Tomi', 'Lola']

# %%
print(names.index('Salamat'))

# %%
poped_name = names.pop(4)
print(poped_name)
print(names)
# Out:
# Salamat
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'funmi', 'Tomi', 'Lola']

# %%
numbers=[1,2,2,3,3,4,2]
print(numbers.count(2))
print(numbers.count(3))
# Out:
# 3
# 2

# %%
names = ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'funmi','Jamilah', 'Lola', 'Hannah']
print(names)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'funmi', 'Jamilah', 'Lola', 'Hannah']

# %%
names.reverse()
print(names)
# Out:
# ['Hannah', 'Lola', 'Jamilah', 'funmi', 'Salamat', 'Carina', 'Esther', 'Zainab', 'Halimah', 'Abiola']

# %%
names=['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'funmi','Jamilah', 'Lola', 'Hannah']
print(names)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'funmi', 'Jamilah', 'Lola', 'Hannah']

# %%
print(list(reversed(names)))
# Out:
# ['Hannah', 'Lola', 'Jamilah', 'funmi', 'Salamat', 'Carina', 'Esther', 'Zainab', 'Halimah', 'Abiola']

# %%
cars = ['Tesla', 'Honda', 'Benz', 'Ford', 'Chevi', 'Audi', 'Toyota']
print (cars)
# Out:
# ['Tesla', 'Honda', 'Benz', 'Ford', 'Chevi', 'Audi', 'Toyota']

# %%
cars=['Tesla', 'Honda', 'Benz', 'Ford', 'Chevi', 'Audi', 'Toyota']
cars.sort() #ascending 
print(cars)

# %%
# Decending order
cars.sort(reverse=True)
print(cars)
# Out:
# ['Toyota', 'Tesla', 'Honda', 'Ford', 'Chevi', 'Benz', 'Audi']

# %%
cars=['Tesla', 'Honda', 'Benz', 'ford', 'Chevi', 'Audi', 'Toyota']
print(sorted(cars))
# Out:
# ['Audi', 'Benz', 'Chevi', 'Honda', 'Tesla', 'Toyota', 'ford']

# %%
names_copy =names.copy()
print(names_copy)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'funmi', 'Jamilah', 'Lola', 'Hannah']

# %%
names_copy.append('Ramat')
print(names_copy)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'funmi', 'Jamilah', 'Lola', 'Hannah', 'Ramat']

# %%
print(names)

# %%
names_copy.clear()
print(names_copy)
# Out:
# []

# %%
print(names)
# Out:
# ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Carina', 'Salamat', 'funmi', 'Jamilah', 'Lola', 'Hannah']

# %%
single_element_tuple = (5)
print(single_element_tuple)

# %%
empty_tuple = ()
single_element_tuple =(5,)
nums = 5,6,5
numbers = (1, 2, 3, 4, 5)
fruits = ("apple", "banana", "cherry")
mixed = (1, "hello", 3.5, True)
nested_tuple = ((1, 2, 3),(4, 5, 6))

print(numbers)
# Out:
# (1, 2, 3, 4, 5)

# %%
single_element_tuple = 5,
print(single_element_tuple)
# Out:
# (5,)

# %%
names = ('Abiola','Halimah', 'Zainab', 'Esther', 'Adijat')
 names [4] = 'Lola'
# Out:
#   Cell In[72], line 2
#     names [4] = 'Lola'
#     ^
# IndentationError: unexpected indent

# %%
names = ('Abiola', 'Halimah', 'Zainab', 'Esther', 'Adijat')
print(names)
names
# Out:
# ('Abiola', 'Halimah', 'Zainab', 'Esther', 'Adijat')
# ('Abiola', 'Halimah', 'Zainab', 'Esther', 'Adijat')

# %%
empty_set = ()
fruits = {"apple", "banana", "cherry"}
numbers = {7, 3, 9, 1, 2, 3, 4, 5}
mixed = {1, "hello", 3.5, True}
xyz = {5,8,4}
print (numbers)
print (xyz)
# Out:
# {1, 2, 3, 4, 5, 7, 9}
# {8, 4, 5}

# %%
print (1==True)
print (0==False)
# Out:
# True
# True

# %%
0==False
1==True
x = {1,2,3, True}
print(x)

# %% [markdown]
# set doesn't duplicate
# Example

# %%
x=

# %%
fruits = {"apple", "banana"}
fruits.add("cherry")
print(fruits)
# Out:
# {'apple', 'cherry', 'banana'}

# %%
fruits = {"apple", "banana"}
fruits.update(("cherry", "orange"))
print (fruits)
# Out:
# {'orange', 'apple', 'cherry', 'banana'}

# %%
fruits = {"apple", "banana", "cherry"}
fruits.remove("banana")
print(fruits)
# Out:
# {'apple', 'cherry'}

# %% [markdown]
# it shows error because the element grape is not found

# %%
fruits.remove("grape")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 fruits.remove("grape")
#
# KeyError: 'grape'

# %%
fruits = {"apple", "banana", "cherry"}
print (fruits)
fruits.discard("banana")
print (fruits)
# Out:
# {'apple', 'cherry', 'banana'}
# {'apple', 'cherry'}

# %%
fruits.discard("grape")
print (fruits)
# Out:
# {'apple', 'cherry'}

# %%
fruits = {"apple", "banana", "cherry"}
fruits.pop()
print (fruits)
# Out:
# {'cherry', 'banana'}

# %%
set1 = {1,2,3}
set2 = {3,4,5}
result = set2.union(set1) 
print(result)
# Out:
# {1, 2, 3, 4, 5}

# %%
set1 = {1,2,3}
set2 = {3,4,5}
result = set1.union(set2) 
print(result)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# Another method in a shorter way
#
# this symbols is called | pipe operator

# %%
result = set1 | set2
print(result)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# intersection() method it returns element present in both set
#
# & it is called ampersand
#
# no 2 with & is the second method

# %%
set1 = {1,2,3,4}
set2 = {3,4,5,6}
result = set1.intersection (set2)
print (result)
# Out:
# {3, 4}

# %%
result = set1 & set2
print(result)
# Out:
# {3, 4}

# %%
set1 = {1,2,3,4}
set2 = {3,4,5,6}
result = set2.difference(set1)
print(result)
# Out:
# {5, 6}

# %%
result = set1 - set2
print(result)
# Out:
# {1, 2}

# %% [markdown]
# symmetric_difference()- Elements in Either set but not both

# %%
set1 = {1,2,3,4}
set2 = {3,4,5,6}
result = set1.symmetric_difference(set2)
print(result)
# Out:
# {1, 2, 5, 6}

# %%
result = set1 ^ set2
print(result)
# Out:
# {1, 2, 5, 6}

# %%
set1 = {1,2,}
set2 = {1,2,3,4}
print(set1.issubset(set2))
# Out:
# True

# %%
print(set1 <= set2)
# Out:
# True

# %%
set1 = {1,2,3,4}
set2 = {1,2}
print (set1.issuperset(set2))
# Out:
# True

# %%
us = {1,2,3,4,5,6,7,8}
set1 = {1,2,3}
set2 ={4,5,6}
print(set1.isdisjoint(set2))
# Out:
# True

# %%
us = {1,2,3,4,5,6,7,8}
set1 = {1,2,3}
set2 ={4,5,6}
print(set1.intersection(set2))
# Out:
# set()

# %% [markdown]
# len() returns the number

# %%
fruits = {"apple", "banana", "cherry"}
print("banana" in fruits)
# Out:
# True

# %%
numbers = {1,2,3,4,5}
print(len(numbers))
# Out:
# 5

# %% [markdown]
# **Creating Dictionary**

# %%
empty_dict = {}
person = {
    "name": "Tomi",
    "age": 20,
    "city": "Ilorin"

}

numbers = {1: "one", 2: "Two", 3: "Three"}
mixed_keys = {"name": "Zinab", 42: "Answer", (1, 2): "Tuple as key"}

print(person['name'])
# Out:
# Tomi

# %%
person = {
    "name": 'Tomi',
    "age": 15,
    "city": "Ilorin",
    'name': 'Salamat',

}

print(person["name"])
print(person["age"])
# Out:
# Salamat
# 15

# %%
numbers [3]
# Out:
# 'Three'

# %%
mixed_keys[(1,2)]
# Out:
# 'Tuple as key'

# %%
print(person["salary"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(person["salary"])
#
# KeyError: 'salary'

# %% [markdown]
# **Using get() to Avoid Errors**

# %%
print(person.get("name"))

print(person.get("salary"))

print(person.get("salary", "Not Available"))
# Out:
# Salamat
# None
# Not Available

# %%
student = {
    "name":"Abiola",
    "age": 15

}
print(student)

student["city"] = "Ilorin"
print (student)
# Out:
# {'name': 'Abiola', 'age': 15}
# {'name': 'Abiola', 'age': 15, 'city': 'Ilorin'}

# %% [markdown]
# **UPDATING AN EXISTING KEY'S VALUES**

# %%
student["age"] = 30
print(student)
# Out:
# {'name': 'Abiola', 'age': 30, 'city': 'Ilorin'}

# %% [markdown]
# **POP() - REMOVE A KEY AND RETURNS ITS VALUE**

# %%
person = {"name": 'Lola',"age": 15, "city": "Lagos"}
print(person)

person.pop("age")
print(person)
# Out:
# {'name': 'Lola', 'age': 15, 'city': 'Lagos'}
# {'name': 'Lola', 'city': 'Lagos'}

# %% [markdown]
# **popitem() - Removes the last inserted Key-Value pair**

# %%
person = {"name": "Esther", "age": 15, "city": "Ilorin"}
print (person)

person.popitem()
print(person)
# Out:
# {'name': 'Esther', 'age': 15, 'city': 'Ilorin'}
# {'name': 'Esther', 'age': 15}

# %% [markdown]
# **del- Deletes a Specific Key**

# %%
person = {"name": "Nofisat", "age":22, "city": "Lagos"}
print(person)

del person ["city"]
print(person)
# Out:
# {'name': 'Nofisat', 'age': 22, 'city': 'Lagos'}
# {'name': 'Nofisat', 'age': 22}

# %%
del person
print(person)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 del person
# ----> 2 print(person)
#
# NameError: name 'person' is not defined

# %% [markdown]
# **clear()- Removes all key-value pairs**

# %%
person = {"name": "Adeola", "age": 15, "city": "Ilorin"}
print (person)

person.clear()
print(person)
# Out:
# {'name': 'Adeola', 'age': 15, 'city': 'Ilorin'}
# {}

# %% [markdown]
# **keys()- Returns all keys**

# %%
Person = {"name": "Ramat", "age": 15,"city": "Ilorin"}
print(person)
print(person.keys())
# Out:
# {'name': 'Jane', 'age': 20, 'city': 'Ilorin'}
# dict_keys(['name', 'age', 'city'])

# %% [markdown]
# **items() - Returns Key-Value Pairs as Tuples**

# %%
print(person)
print(person.items())
# Out:
# {'name': 'Jane', 'age': 20, 'city': 'Ilorin'}
# dict_items([('name', 'Jane'), ('age', 20), ('city', 'Ilorin')])

# %% [markdown]
# **updates() - Merges Two Dictionaries**
# updates the dictionary with key-value pairs from another dictionary.

# %%
person = {"name": "Jemilah", "age": 15}
print(person)

new_data = {"city": "Ilorin", "age": 25}
person.update(new_data)
print(person)
# Out:
# {'name': 'Jemilah', 'age': 15}
# {'name': 'Jemilah', 'age': 25, 'city': 'Ilorin'}

# %% [markdown]
# **USING in Keyword**

# %%
person = {"name": "Jane", "age": 20}
print(person)

print('name' in person)
print('Salary' in person)
# Out:
# {'name': 'Jane', 'age': 20}
# True
# False

# %% [markdown]
# **Copy() - Creates a copy**

# %%
person = {"name": "Jane", "age": 20, "city": 'Ilorin'} 
print(person)

copy_dict = person.copy()
print(copy_dict)
# Out:
# {'name': 'Jane', 'age': 20, 'city': 'Ilorin'}
# {'name': 'Jane', 'age': 20, 'city': 'Ilorin'}

# %% [markdown]
# Short challenge

# %% [markdown]
# **len() - Returns the Number of Key_value Pairs**

# %%
print(len(person))
# Out:
# 3

# %% [markdown]
# **Nested Dictionaries**
#
# A dictionary can contain another dictionary

# %%
student = {
    "name": "Rukayat",
    "grades": {"math": 90, "Science":85}

}
print(student["grades"]["math"])
# Out:
# 90

# %%
l = ['reading', 'travelling', [1, 2,7], 'cooking']
l[2][2]
# Out:
# 7

# %%
Small Chanllege

# %%
student = {
    "name": "Funmi",
    "info": {"age":20, "hobbies": ['reading', 'travelling', 'cooking']}

}


print(student['info']['hobbies'][1])
# Out:
# travelling

# %%
xyz = input('Enter anything here: ')
print (xyz)
# Out:
# Enter anything here:  Hello Tomi
# Hello Tomi

# %%
name = input (" Enter)

# %% [markdown]
# Challenge
# A theater has seats represented as tuples (row, col).

# %%
reservation_a = ((1,1), (1,2), (2,1), (2,3))
reservation_b = ((2,1), (2,2), (1,1), (3,3))
common_seats = tuple(set(reservation_a) & set(reservation_b))
print(common_seats)
# Out:
# ((1, 1), (2, 1))

# %%
preference={"theme":"dark","language":"en"}
print(preference.get("font_size",12))
# Out:
# 12

# %%
num_int = 5
num_float = num_int + 2.5

print(num_float)
print(type(num_float))
# Out:
# 7.5
# <class 'float'>

# %%
num_complex = num_int + 3j
print(num_complex)
print(type(num_complex))
# Out:
# (7+3j)
# <class 'complex'>

# %%
num_float = 7.0
num_int =int(num_float)

print(num_int)
print(type(num_int))
# Out:
# 7
# <class 'int'>

# %%
num_str = "123"
num_int = int(num_str)
print (num_int)
print(type(num_int))
# Out:
# 123
# <class 'int'>

# %%
age = 25
age_str = str(age)

print(age_str)
print(type(age_str))
# Out:
# 25
# <class 'str'>

# %%
num_str = "45.6"
num_float = float(num_str)

print(num_float)
print(type(num_float))
# Out:
# 45.6
# <class 'float'>

# %%
invalid_str = "45a"
invalid_str = int(invalid_str)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 invalid_str = "45a"
# ----> 2 invalid_str = int(invalid_str)
#
# ValueError: invalid literal for int() with base 10: '45a'

# %%
print(bool(0))
print(bool(1))
print(bool(""))
print(bool("hello"))
print(bool([]))
print(bool([1,2]))
# Out:
# False
# True
# False
# True
# False
# True

# %%
name = input ("Enter anything here: ")
print(f"Hello,{name}!")
(f"Hello,{name.upper()}!")
# Out:
# Enter anything here:  tomi
# Hello,tomi!
# 'Hello,TOMI!'

# %%
age = input("Enter your age: ")
print(type(age))
print(f" You are {age} years old.")
# Out:
# Enter your age:  12
# <class 'str'>
#  You are 12 years old.

# %%
age = int(input("Enter your age: "))
print(type(age))
print(f"You are {age} years old.")
# Out:
# Enter your age:  65
# <class 'int'>
# You are 65 years old.

# %%
xyz = input ('enter full name: ').split
# Out:
# enter full name:  tomi yemi

# %%
xyz = input ('enter full name: ')
print(xyz.split())
# Out:
# enter full name:  tomi yemi
# ['tomi', 'yemi']

# %%
height = float(input("Enter your height in meters: "))
print(f"Your height is {height} m")
# Out:
# Enter your height in meters:  6.1
# Your height is 6.1 m

# %%
is_student = bool(input("Are you a student? Enter 1 for Yes, 0 for No: "))
print(f"Student status: {is_student} ")
# Out:
# Are you a student? Enter 1 for Yes, 0 for No:  True
# Student status: True

# %%
import math

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
print(math.pow(2,3))
print(2**3.0)
# Out:
# 8.0
# 8.0

# %%
print(2**3)
print(math.pow(2,3))
# Out:
# 8
# 8.0

# %%
2*3
# Out:
# 6

# %%
print(math.floor(4.7))
# Out:
# 4

# %%
print(math.ceil(4.1))
# Out:
# 5

# %%
print(math.log(10))
print(math.log(10,2))
# Out:
# 2.302585092994046
# 3.3219280948873626

# %%
# Base 10 Logarithm

print(math.log10(100))
# Out:
# 2.0

# %%
print(math.sin(10))
# Out:
# -0.5440211108893698

# %%
print(math.cos(90))
# Out:
# -0.4480736161291702

# %%
print(math.tan(math.pi/4))
# Out:
# 0.9999999999999999

# %%
print(math.asin(1))
print(math.acos(0))
print(math.atan(1))
# Out:
# 1.5707963267948966
# 1.5707963267948966
# 0.7853981633974483

# %%
# Alias

import math as m

# %% [raw]
# m.pi

# %%
import random

# %%
random_num = random.random()
print(random_num)
# Out:
# 0.6788645615291456

# %%
random_num = random.randint(1,10)
random_num
# Out:
# 6

# %%
random_num = random.randint(-1,10)
random_num
# Out:
# 7

# %%
random_num = random.uniform(1,5)
print(random_num)
# Out:
# 3.1839891616372777

# %% [markdown]
# Random Choice from a LIST
# Select a Random Element (random.choice())

# %%
names = ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Lola', 'Carina', 'Salamat', 'Funmi', 'Zainab', 'Lola', 'Hannah', 'Tomi']
random_name = random.choice(names)
print(random_name)
# Out:
# Tomi

# %%
two_random_names = random.sample(names,3)
print(two_random_names)
# Out:
# ['Lola', 'Zainab', 'Funmi']

# %%
names = ['Abiola', 'Halimah', 'Zainab', 'Esther', 'Lola', 'Carina', 'Salamat', 'Funmi', 'Zainab', 'Lola', 'Hannah', 'Tomi']
random.shuffle(names)
print(names)
# Out:
# ['Zainab', 'Tomi', 'Hannah', 'Salamat', 'Halimah', 'Funmi', 'Lola', 'Lola', 'Carina', 'Zainab', 'Abiola', 'Esther']

# %%
x = 4
print(math.pow(4,4))
# Out:
# 256.0

# %%
import random

# %%
x = random.randint(1, 20)
print(x)
print(x**2)
# Out:
# 9
# 81

# %%
a = 10
b = 3
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a % b)
print(a ** b)


print(f'10 divide 3 is {a // b}, and the remainder is {(a % b)} ')
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000
# 10 divide 3 is 3, and the remainder is 1

# %%
x = 10
y = 5

print(x == y)
print(x != y)
print(x > y)
print(x < y)
print(x >= y)
print(x <= y)
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# Logical Operators
# for combining more than one conparixson

# %%
x = 5
y = 10
z = 15

print (x < y or x > z)

print(x > 4 and y < z)
print(x > 5 or y > 10)
print(not(x > 5 ))
# Out:
# True
# True
# False
# True

# %%
a = 5
b = 3

print (a & b)
print (a | b)
print(a ^ b)
print (~a)
print(a << 1)
print(a >> 1)
# Out:
# 1
# 7
# 6
# -6
# 10
# 2

# %%
x = 10
x += 5
x
# Out:
# 15

# %%
balance = 190000
credit = 20000
balance = balance + credit
#balance +=credit
balance
# Out:
# 210000

# %%
balance = 19000
debit = 3000

#balance = balance - debit
balance -=debit
balance
# Out:
# 16000

# %%
balance = 20
debit = 5
#balance = balance * debit
balance *=debit
balance
# Out:
# 100

# %%
balance = 20
debit = 3
#balance = balance // debit
balance //=debit
balance
# Out:
# 6

# %%
balance = 20
debit = 3
#balance = balance % debit
balance %=debit
balance
# Out:
# 2
